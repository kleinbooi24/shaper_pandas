# %% [markdown]
# How many transections were paid via M-Pesa send money?

# %%
#Import the important libraries

import pandas as pd 
import matplotlib.pyplot as plt

#Import the Data from the CSV file

money_df = pd.read_csv("Money.csv")

money_df.head(3)
# Out:
#          MERCHANT_CATEGORIZED_AT  HOURS  MONTHS  MINUTES  YEAR  \
# 0  2022-05-04 10:25:50.588042+00     10       5       25  2022
# 1  2021-10-25 16:18:38.586837+00     16      10       18  2021
# 2  2022-05-20 14:17:30.917297+00     14       5       17  2022
#
#                        MERCHANT_NAME MERCHANT_CATEGORIZED_AS  PURCHASE_VALUE  \
# 0  UONSDA CHURCH  MOGERE MWAYO TITHE         Rent / Mortgage            1700
# 1                          PARK N GO        Transport & Fuel             100
# 2         SAFARICOM OFFERS  TUNUKIWA             Data & WiFi              20
#
#              PURCHASED_AT  IS_PURCHASE_PAID_VIA_MPESA_SEND_MONEY  USER_AGE  \
# 0  2022-05-04 13:56:00+00                                  False       NaN
# 1  2021-10-24 14:12:00+00                                  False      25.0
# 2  2022-05-27 12:46:00+00                                  False       NaN
#
#   USER_GENDER  USER_HOUSEHOLD  USER_INCOME      USER_ID Transaction_ID
# 0        Male               3        10000  ID_ZX4DCF4K    ID_04mk78fa
# 1      Female               4        90000  ID_U9WZMGJZ    ID_04xkfb07
# 2        Male               3        10000  ID_ZX4DCF4K    ID_051urwuw

# %%
# PULL THE DATA TO BE USED
# We want to count the number of transactions paid via MPESA Send Money

#APPROACH: Filter the transaction paid via MPESA as True

mpesa_transactions_df = money_df[money_df["IS_PURCHASE_PAID_VIA_MPESA_SEND_MONEY"] == True]

mpesa_transactions_df
# Out:
#            MERCHANT_CATEGORIZED_AT  HOURS  MONTHS  MINUTES  YEAR  \
# 5    2022-01-07 09:41:44.286084+00      9       1       41  2022
# 12    2022-06-01 10:23:56.42678+00     10       6       23  2022
# 13   2021-09-01 02:19:31.317098+00      2       9       19  2021
# 15   2022-03-16 13:05:51.851102+00     13       3        5  2022
# 16   2022-04-12 15:59:14.139347+00     15       4       59  2022
# ..                             ...    ...     ...      ...   ...
# 365  2022-03-16 13:08:19.703288+00     13       3        8  2022
# 367  2022-03-16 13:05:51.851102+00     13       3        5  2022
# 368  2021-08-06 11:28:03.723042+00     11       8       28  2021
# 369  2022-04-12 15:57:05.758311+00     15       4       57  2022
# 371   2021-10-05 12:29:13.14963+00     12      10       29  2021
#
#               MERCHANT_NAME MERCHANT_CATEGORIZED_AS  PURCHASE_VALUE  \
# 5            JOSEPH NTHENGE           Miscellaneous           14800
# 12       ELIZABETH NYAMBURA               Groceries             300
# 13           SAFARICOM POST             Data & WiFi            3000
# 15             KPLC PREPAID            Bills & Fees            1000
# 16            TABITHA RAORE        Family & Friends           19000
# ..                      ...                     ...             ...
# 365           CEDRIC OCHOLA        Family & Friends             250
# 367             NIMROD ZIRO        Family & Friends            2000
# 368         ONESMUS  GAKURU           Miscellaneous             500
# 369          GLADWELL MBURU           Miscellaneous             400
# 371  EQUITY PAYBILL ACCOUNT            Bills & Fees           14000
#
#                PURCHASED_AT  IS_PURCHASE_PAID_VIA_MPESA_SEND_MONEY  USER_AGE  \
# 5    2022-01-08 12:56:00+00                                   True      27.0
# 12   2021-06-17 11:17:00+00                                   True       NaN
# 13   2021-09-23 08:15:00+00                                   True      25.0
# 15   2022-03-11 06:49:00+00                                   True       NaN
# 16   2021-12-18 15:15:00+00                                   True       NaN
# ..                      ...                                    ...       ...
# 365  2022-03-22 10:59:00+00                                   True       NaN
# 367  2021-12-27 20:14:00+00                                   True       NaN
# 368  2021-08-26 13:38:00+00                                   True      27.0
# 369  2022-04-03 08:39:00+00                                   True       NaN
# 371  2021-10-08 10:33:00+00                                   True      25.0
#
#     USER_GENDER  USER_HOUSEHOLD  USER_INCOME      USER_ID Transaction_ID
# 5        Female               2         8000  ID_L8QMYB09    ID_0ntvo3wr
# 12       Female               1        85000  ID_1I8XYBWK    ID_1dzb2jew
# 13       Female               4        90000  ID_U9WZMGJZ    ID_1ev8a8nu
# 15         Male               1       200000  ID_5Y35KI6Q    ID_1kmitbhe
# 16         Male               5       252000  ID_3JA0MAFB    ID_1mzk2n06
# ..          ...             ...          ...          ...            ...
# 365        Male               5       150000  ID_O8P8YS18    ID_zcrvugl9
# 367      Female               1       250000  ID_OZANC6XT    ID_zh4nw2s0
# 368      Female               2         8000  ID_L8QMYB09    ID_zr5x8yjs
# 369        Male               5       750000  ID_D8FOVVBB    ID_zty81sq8
# 371      Female               4        90000  ID_U9WZMGJZ    ID_zx9hnvvb
#
# [170 rows x 16 columns]

# %%
# Count the number of transactions

No_of_MPESA_Transactions = len(mpesa_transactions_df)

print(f"No of Mpesa Transactions = {No_of_MPESA_Transactions}")
# Out:
# No of Mpesa Transactions = 170
